# %% [markdown]
# # Parametrische Identifikation mit OBF im Vergleich zu ARX Modellen
# # Beispiel: System erster Ordnung

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.signal as sp
from random import gauss
from random import seed
from pandas import Series
import control as ctl
import control.matlab as cnt
# %matplotlib inline

# %% [markdown]
# Erzeugung eines Testsystems

# %%
ts = 1
num = [1.0]
den = [1.0, -0.95]
sys_test = ctl.tf(num, den, ts)
sys_test
# Out:
# TransferFunction(array([1.]), array([ 1.  , -0.95]), 1)

# %% [markdown]
# Erzeugung von Testsignalen:
# Als exogenes Eingangssignal wird eine Abfolge zufälliger Sprungantworten verwendet.
# Als Störsignal am Ausgang (Messrauschen) gaussverteiltes weisses Rauschen.

# %%
# Länge der Zeitreihe
n_iter = 1000
Time = np.linspace(0,n_iter-1,n_iter)
# Exogenes Signal 
input_sequence = [np.random.randint(-1, 1) for i in range(n_iter)]
# Störung
noise_sequence = [gauss(0.0, 2) for i in range(n_iter)]

plt.figure()
plt.plot(Time, input_sequence)
plt.xlabel('Time')
plt.ylabel('u(k)')
plt.title("Eingangssignal")
# Out:
# Text(0.5, 1.0, 'Eingangssignal')

# %%
plt.figure()
plt.plot(Time, noise_sequence)
plt.xlabel('Time')
plt.ylabel('v(k)')
plt.title("Messrauschen")
# Out:
# Text(0.5, 1.0, 'Messrauschen')

# %% [markdown]
# Berechnung des Ausgangssignals durch Simulation

# %%
# Simulation des ARX Modells 
# Anm. auch einige Befehle in Toolboxen verfügbar, deren Nutzung sich bei Systemen höherer Ordnung anbietet
t = np.arange(n_iter)
output_sequence = np.zeros(n_iter)
for k in range(n_iter-1):
    output_sequence[k+1] = np.dot([1,0.95], [input_sequence[k], output_sequence[k]])

# %%
plt.figure()
plt.plot(Time, input_sequence, label='input')
plt.plot(Time, output_sequence, label='output')
plt.xlabel('Time []')
legend = plt.legend()

# %% [markdown]
# Nichtparametrische Schätzung des Frequenzgangs

# %%
f, R_yx = sp.csd(input_sequence, np.transpose(output_sequence), nperseg=n_iter, noverlap=0)
f, R_xx = sp.welch(input_sequence, nperseg=n_iter, noverlap=0)

H_est = R_yx/R_xx

plt.figure()
plt.loglog(f,np.abs(np.transpose(H_est)))
plt.xlabel('normalized frequency')
plt.ylabel('abs(H)')
# Out:
# Text(0, 0.5, 'abs(H)')

# %% [markdown]
# ARX Schätzung des Systems

# %%
# Regressor
phi = np.zeros((n_iter, 2))
for k in range(n_iter):
    phi[k, :] = [input_sequence[k-1], output_sequence[k-1]]
# Lösung des linearen Gleichungssystems
ARX, residuals, rank, s = np.linalg.lstsq(phi,output_sequence,-1)
print(ARX)

# Simulation des ARX Modells 
output_arx = np.zeros(n_iter)
for k in range(n_iter-1):
    output_arx[k+1] = np.dot(ARX, [input_sequence[k], output_arx[k]])

# Zur Validierung wird der Frequenzgang des Modells aus den simulierten Zeitreihen bestimmt und mit der black-box-Schätzung verglichen:
f, R_yx = sp.csd(input_sequence, np.transpose(output_arx), nperseg=n_iter, noverlap=0)
f, R_xx = sp.welch(input_sequence, nperseg=n_iter, noverlap=0)

H_arx = R_yx/R_xx

plt.figure()
plt.plot(Time, input_sequence, label='input')
plt.plot(Time, output_arx, label='output')
plt.plot(Time, output_sequence, label='output')
plt.xlabel('Time []')
legend = plt.legend()
# Out:
# [0.9794954  0.94996012]

# %% [markdown]
# Vergleich der Ergebnisse - parametrische und nichtparametrische Schätzung

# %%
plt.figure()
plt.loglog(f,abs(np.transpose(H_arx)),label='ARX Modell') #Identifikation mit der sysid Toolbox sippy

plt.loglog(f,np.abs(np.transpose(H_est)),label='Black Box') #Black Box Modell
plt.xlabel('normalized frequency')
plt.ylabel('|H|')
legend = plt.legend()

# %% [markdown]
# ## Überlagerung eines Messrauschens
#
# Die Identifikation wird wiederholt, nachdem ein Messrauschen als Störsignal das Ausgangssignal überlagert.

# %% [markdown]
# ![output_error.png](attachment:output_error.png)

# %%
output_noisy = np.transpose(noise_sequence  + np.transpose(output_sequence))

# %%
plt.figure()
plt.plot(Time, output_noisy, label = 'output noise')
plt.plot(Time, output_sequence, label = 'no noise')

plt.xlabel('Time []')
legend = plt.legend()

# %% [markdown]
# Erneut erfolgt die Identifikation eines ARX Modells

# %%
# Regressor
phi = np.zeros((n_iter, 2))
for k in range(n_iter):
    phi[k, :] = [input_sequence[k-1], output_noisy[k-1]]
# Lösung des linearen Gleichungssystems
ARX_noisy, residuals, rank, s = np.linalg.lstsq(phi,output_noisy,-1)
print(ARX_noisy)
# Simulation des ARX Modells 
output_arx_noisy = np.zeros(n_iter)
for k in range(n_iter-1):
    output_arx_noisy[k+1] = np.dot(ARX_noisy, [input_sequence[k], output_arx_noisy[k]])
#Berechnung des Frequenzgangs aus den simulierten Zeitreihen
f, R_yx = sp.csd(input_sequence, np.transpose(output_arx_noisy), nperseg=n_iter, noverlap=0)
f, R_xx = sp.welch(input_sequence, nperseg=n_iter, noverlap=0)

H_arx_noisy = R_yx/R_xx
# Out:
# [1.448593  0.8935384]

# %% [markdown]
# Offensichtlich weichen die Ergebnisse der Identifikation deutlich von den Systemparametern ab, da das Messrauschen zu einem Bias in der ARX Schätzung führt.
# Dies wird auch im Vergleich der Frequenzgänge beider Modelle deutlich:

# %%
plt.figure()
plt.loglog(f,abs(np.transpose(H_arx)),label='ARX Modell') 

plt.loglog(f,np.abs(np.transpose(H_arx_noisy)),label='ARX Modell, Messrauschen') 
plt.xlabel('normalized frequency')
plt.ylabel('|H|')
legend = plt.legend()

plt.xlabel('normalized frequency')
plt.ylabel('|H|')
legend = plt.legend()

# %% [markdown]
# ## Schätzung durch orthonormale Basisfunktionsmodelle: Laguerre- Funktionen
#
# Dieses Modell besitzt bei Messrauschen keinen Bias.

# %% [markdown]
# Der freie Parameter (Pol der Übertragungsfunktionen der Laguerre-Filterbank) wird aus der vorherigen Schätzung des ARX-Modells gewonnen.

# %%
# Setze a gleich dem Pol der ARX-SChätzung 
a = ARX_noisy[1]

# %% [markdown]
# Aufbau der Elemente der Filterbank

# %%
# Tiefpass 
sys_1 = ctl.tf([np.sqrt(1-a**2)], [1, -a], ts)
# Allpass
sys_2 = ctl.tf([-a, 1], [1, -a], ts)

# %%
sys_1
# Out:
# TransferFunction(array([0.44898678]), array([ 1.       , -0.8935384]), 1)

# %%
sys_2
# Out:
# TransferFunction(array([-0.8935384,  1.       ]), array([ 1.       , -0.8935384]), 1)

# %% [markdown]
# Berechnung der Impulsantworten

# %%
Time = np.linspace(0,n_iter-1,n_iter)
Time, h = ctl.impulse_response(sys_1, Time)

plot_length = 300
sys_n = sys_1

plt.figure()
plt.plot(Time[1:plot_length], h.T[1:plot_length], label='Laguerre- Funktion l_1')

for n in range(3):
    sys_n = ctl.series(sys_n, sys_2)
    Time, h = ctl.impulse_response(sys_n, Time)
    plt.plot(Time[1:plot_length], h.T[1:plot_length], label='Laguerre- Funktion l_'+str(n+2))
    
plt.legend()
plt.xlabel('Time')
plt.ylabel('l')
# Out:
# Text(0, 0.5, 'l')

# %% [markdown]
# Aufbau der Regressionsmatrix

# %%
# Modellordnung N
N = 4
# Länge der Zeitreihe zur Identifikation
K = 300

Time = np.linspace(0, K-1, K)
phi_mat = np.zeros((K, N))
# Bestimmung der Matrix aus der Filterung des Eingangssignals mit der Filterbank
Time, h = ctl.forced_response(sys_1, Time, input_sequence[0:K])
phi_mat[:,0] = h
sys_n = sys_1

for n in range(N-1):
    sys_n = ctl.series(sys_n, sys_2)
    Time, h = ctl.forced_response(sys_n, Time, input_sequence[0:K])
    phi_mat[:,n+1] = h

# %% [markdown]
# Lösen des überbestimmten Gleichungssysstems

# %%
THETA = np.dot(np.linalg.pinv(phi_mat), output_noisy[0:K])
print(THETA)
# Out:
# [2.96167949 1.26943669 0.24669561 0.21012394]

# %% [markdown]
# Aufbau des Modells durch Linearkombination der Übertragungsfunktionen mit den Komponenten des Parametervektors

# %% [markdown]
# Berechnung des Ausgangssignals der Filterbank

# %%
y_dach = np.dot(phi_mat,THETA)

# %% [markdown]
# Der Vergleich mit dem ungestörten Ausgangssignal zeigt, dass die Identifikation mit OBF auch bei stark verrauschten Ausgangssignalen und einer mäßig guten Parametrierung gute Ergebnisse liefern kann.

# %%
plt.figure()
plt.plot(Time, output_noisy[0:K], label = 'output w/ noise')
plt.plot(Time, output_sequence[0:K], label = 'output w/o noise')
plt.plot(Time, y_dach, label = 'Laguerre model')
plt.xlabel('Time []')
legend = plt.legend()

# %% [markdown]
# ## Validierung im Zeitbereich
#
# Hierfür wird ein Abschnitt der Zeitreihe, der nicht für die Identifikation genutzt wurde, verwendet. So kann entdeckt werden, ob das Modell unabsichtlich zu stark an die zur Identifikation verwendete Zeitreihe (oder das Messrauschen) angepasst wurde (Overfitting).

# %%
# Länge der Zeitreihe
K = 500

# Offset in der Zeitreihe: Validierung mit einem anderen Abschnitt des Signals als zuvor verwendet
Offset = 400

Time = np.linspace(0, K-1, K)
phi_mat = np.zeros((K, N))

Time, h = ctl.forced_response(sys_1, Time, input_sequence[Offset:Offset+K])
phi_mat[:,0] = h
sys_n = sys_1

for n in range(N-1):
    sys_n = ctl.series(sys_n, sys_2)
    Time, h = ctl.forced_response(sys_n, Time, input_sequence[Offset:Offset+K])
    phi_mat[:,n+1] = h

# %%
y_dach = np.dot(phi_mat,THETA)

# %%
plt.figure()
plt.plot(Time+Offset, output_noisy[Offset:Offset+K], label = 'output w/ noise' )
plt.plot(Time+Offset, output_sequence[Offset:Offset+K], label = 'output w/o noise')
plt.plot(Time+Offset, y_dach, label = 'Laguerre model')
plt.xlabel('Time []')
legend = plt.legend()

# %% [markdown]
# Zum Vergleich: Ausgangssignal des ARX-Modells

# %%
num = [ARX_noisy[0]]
den = [1.0, -ARX_noisy[1]]
sys_ARX_noisy = ctl.tf(num, den, ts)
sys_ARX_noisy
# Out:
# TransferFunction(array([1.448593]), array([ 1.       , -0.8935384]), 1)

# %%
Time, y_ARX_noisy = ctl.forced_response(sys_ARX_noisy, Time, input_sequence[Offset:Offset+K])

# %%
plt.figure()
plt.plot(Time+Offset, output_sequence[Offset:Offset+K], label = 'output w/o noise' )
plt.plot(Time+Offset, y_dach, label = 'Laguerre model')
plt.plot(Time+Offset, y_ARX_noisy.T, label = 'ARX model')
plt.xlabel('Time []')
legend = plt.legend()

# %%
sys_M1 = sys_1
sys_M1 = ctl.series(sys_M1, THETA[0])

sys_modell = sys_M1

sys_n = sys_1

for n in range(N-1):
    sys_n = ctl.series(sys_n,sys_2)
    sys_Mn = sys_n
    sys_Mn = ctl.series(sys_Mn, THETA[n+1])
    sys_modell = ctl.parallel(sys_modell, sys_Mn)
    
laguerre_mod = sys_modell

# %%
ctl.bode_plot(
    [laguerre_mod, sys_test],
    label=["Laguerre", "System"],
    show_legend=True)

# %%
plt.figure()
#plt.loglog(omega/(2*np.pi),mag,label='ARX Modell') #Identifikation mit der sysid Toolbox sippy
#plt.loglog(omega_n/(2*np.pi),mag_n,label='ARX Modell, mit Ausgangsrauschen') #Identifikation mit der sysid Toolbox sippy
#plt.loglog(omega_l/(2*np.pi),mag_l,label='Laguerre Modell') 

plt.xlabel('normalized frequency')
plt.ylabel('|H|')
legend = plt.legend()
